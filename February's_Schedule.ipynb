# %% [markdown]
# <a href="https://colab.research.google.com/github/dewcxiv/Test_2025/blob/main/February's_Schedule.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
schedule = {
    1: ["미아랑 데이투 (8AM)"],
    2: ["Car Freeday (6AM)"],
    3: ["이차언니랑 만나기 (6PM)"],
    11: ["Flying Jump (7PM)"],
    14: ["케이크 데이 (12PM)"],
    23: ["Kiss of Life Ticketing Day (12PM)"]
}

# %%
df = pd.DataFrame(list(schedule.items()), columns=["Date", "Event"])
df["Date"] = df["Date"].astype(str)

# %%
df
# Out:
#   Date                                Event
# 0    1                      [미아랑 데이투 (8AM)]
# 1    2                  [Car Freeday (6AM)]
# 2    3                    [이차언니랑 만나기 (6PM)]
# 3   11                  [Flying Jump (7PM)]
# 4   14                      [케이크 데이 (12PM)]
# 5   23  [Kiss of Life Ticketing Day (12PM)]

# %%
#Create an Interactive Calendar UI
import ipywidgets as widgets
from IPython.display import display

# %%
date_dropdown = widgets.Dropdown(
    options=[str(d) for d in sorted(schedule.keys())],
    description="Date:",
    style={'description_width':'initial'}
)

# %%
def show_event(date):
    date = int(date)
    event = schedule.get(date, ["No events scheduled."])
    print(f"📅 Events on {date} February:")
    for e in event:
        print(f"    -{e}")

# %%
widgets.interactive(show_event, date=date_dropdown)
# Out:
# interactive(children=(Dropdown(description='Date:', options=('1', '2', '3', '11', '14', '23'), style=Descripti…
