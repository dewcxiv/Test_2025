# %% [markdown]
# <a href="https://colab.research.google.com/github/dewcxiv/Test_2025/blob/main/Pie_Chart_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Python Syntax (Variables, Data Types, Operators

# %% [markdown]
# **1. Variables in Python**

# %%
# !pip install matplotlib

# %%
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import pandas as pd
from datetime import datetime, timedelta

# %%
activities = [
    ("Wake up, Morning Walk", "05:30", "07:00"),
    ("Hutan Kota Picnic", "07:00", "09:00"),
    ("Photobooth at Blok M, Cafe", "09:30", "10:30"),
    ("Lunch", "11:00", "12:00"),
    ("Home", "12:30"),
    ("Doing nothing like you own the world", "13:00", "22:00"),
    ("Sleep", "22:00", "05:30")
]

schedule = []
for activity, start_time, end_time in activities:
    # Handle case where end time is after midnight
    start = datetime.strptime(start_time, "%H:%M")
    end = datetime.strptime(end_time, "%H:%M")
    schedule.append((activity, start, end)) # Append to schedule

fig, ax = plt.subplots(figsize=(10,6))

for i, (activity, start, end) in enumerate(schedule):
    ax.barh(activity, (end - start).seconds / 3600, left=start, color='skyblue', edgecolor='black')

ax.set_xlabel('Time')
ax.set_ylabel('Activity')
ax.set_title('Dewi\'s Schedule January 25th 2025')
ax.set_xlim([datetime.strptime("05:30", "%H:%M"), datetime.strptime("22:00", "%H:%M")])
ax.xaxis.set_major_locator(mdates.HourLocator(interval=1))
ax.xaxis.set_major_formatter(mdates.DateFormatter("%H:%M"))
ax.grid(True)

plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-29-9305093e73d1> in <cell line: 0>()
#      10
#      11 schedule = []
# ---> 12 for activity, start_time, end_time in activities:
#      13     # Handle case where end time is after midnight
#      14     start = datetime.strptime(start_time, "%H:%M")
#
# ValueError: not enough values to unpack (expected 3, got 2)

# %%
activities = [
    ("Wake up, Morning Walk", "05:30", "07:00"),
    ("Hutan Kota Picnic", "07:00", "09:00"),
    ("Photobooth at Blok M, Cafe", "09:30", "10:30"),
    ("Lunch", "11:00", "12:00"),
    ("Home", "12:30", "13:00"),  # Added an end time for "Home"
    ("Doing nothing like you own the world", "13:00", "22:00"),
    ("Sleep", "22:00", "05:30")
]

schedule = []
for activity, start_time, end_time in activities:
    # Handle case where end time is after midnight
    start = datetime.strptime(start_time, "%H:%M")
    end = datetime.strptime(end_time, "%H:%M")
    schedule.append((activity, start, end)) # Append to schedule

# %%
fig, ax = plt.subplots(figsize=(10,6))

for i, (activity, start, end) in enumerate(schedule):
    ax.barh(activity, (end - start).seconds / 3600, left=start, color='skyblue', edgecolor='black')

ax.set_xlabel('Time')
ax.set_ylabel('Activity')
ax.set_title('Dewi\'s Schedule January 25th 2025')
ax.set_xlim([datetime.strptime("05:30", "%H:%M"), datetime.strptime("22:00", "%H:%M")])
ax.xaxis.set_major_locator(mdates.HourLocator(interval=1))
ax.xaxis.set_major_formatter(mdates.DateFormatter("%H:%M"))
ax.grid(True)

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
from datetime import datetime, timedelta

# Define daily activities and their start and end times
activities = [
    ("Wake up, Morning Walk", "05:30", "07:00"),
    ("Hutan Kota Picnic", "07:00", "09:00"),
    ("Photobooth at Blok M, Cafe", "09:30", "10:30"),
    ("Lunch", "11:00", "12:00"),
    ("Home", "12:30", "13:00"),  # Added an end time for "Home"
    ("Doing nothing like I own the world", "13:00", "22:00"),
    ("Sleep", "22:00", "05:30")
]

# Prepare labels with the actual time schedule (e.g., "06:00 - 07:00: Wake up")
time_labels = []
durations = []
start_times = []
for activity, start_time, end_time in activities:
    start = datetime.strptime(start_time, "%H:%M")
    end = datetime.strptime(end_time, "%H:%M")

    # If the end time is before the start time, add one day to the end time
    if end < start:
        end += timedelta(days=1)

    # Calculate the duration in hours
    duration = (end - start).seconds / 3600  # Convert seconds to hours
    time_labels.append(f"{start_time} - {end.strftime('%H:%M')}: {activity}")
    durations.append(duration)
    start_times.append(start)

# Normalize the starting times to be relative to a 24-hour period
start_times = [start.hour + start.minute / 60 for start in start_times]

# Create a pie chart to visualize the schedule with time and activities in a clock-like manner
fig, ax = plt.subplots(figsize=(8, 8))

# Create a pie chart
ax.pie(durations, labels=time_labels, startangle=90, counterclock=False, colors=plt.cm.Paired.colors, wedgeprops={'edgecolor': 'black'})

# Add a title and adjust the chart to look like a clock
ax.set_title('Dewi\'s schedule', fontsize=14)
ax.axis('equal')  # Equal aspect ratio ensures that pie chart is circular.

# Show the pie chart
plt.tight_layout()
plt.show()
